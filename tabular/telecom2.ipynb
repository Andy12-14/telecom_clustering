# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.pipeline import Pipeline

# %%
# Just loading the dataseyt for now and visualizing the first 5 rows
df = pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/churn_telecom.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service     Fiber optic             No  ...               No
# 1                No     Fiber optic            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service     Fiber optic            Yes  ...              Yes
# 4                No             DSL             No  ...               No
#
# ...

# %%
def summary(df):
  """ We are making an function that will make the analysis of the dataframe.
  """
  print(f"There's {df.shape[0]} rows and {df.shape[1]} columns in the dataframe")
  print()
  print(f"There's {df.isna().sum().sum()} missing values in the dataframe")
  print()
  print(f"Il y a {df.shape[0] - df.drop_duplicates().shape[0]} doublons")
  print()
  print(f"The columns are {df.columns.to_list()}")
  print()

summary(df)
# Out:
# There's 7043 rows and 21 columns in the dataframe
#
# There's 0 missing values in the dataframe
#
# Il y a 0 doublons
#
# The columns are ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
# We are going to display the types of every columns now to see if it matches
cols = df.columns.to_list()

print(df[cols].dtypes)
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# we got an error on the previous cell because there's the character ' ' in the column that can't be converted into float
# so we should handle it first

df["TotalCharges"] = df['TotalCharges'].replace(" ", np.nan)

# We transform the " " into nan so that the whole column can be converted in float

df["TotalCharges"] = df["TotalCharges"].astype(float)
# Now i got to verify the percentage of nan and make an decision based of it
print("\nThe percentage of NaNs")
print((df.isna().sum()*100)/len(df))

# The percentage is really low so i will drop them


display(df.head())
# Out:
# The percentage of NaNs
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# Partner             0.000000
# Dependents          0.000000
# tenure              0.000000
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.156183
# Churn               0.000000
# dtype: float64
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# ...

# %%
# As the totalcharges have some missing values we fill them total charges is monthly charges by the number of month so that is what we did 

df["TotalCharges"] = df['TotalCharges'].fillna(df['tenure'] * df['MonthlyCharges'])
print("\nThe percentage of NaNs")
print()
print((df.isna().sum()*100)/len(df))
# Out:
# The percentage of NaNs
#
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
# A few important telecom metrics that we calculate by ourselves

attrition_rate = (len(df[df["Churn"] == "Yes"]) / df.shape[0]) * 100


retention_rate = 100 - attrition_rate

avg_lifespan = attrition_rate / 10


print(f"the attrition rate is : {attrition_rate}, the retention rate is : {retention_rate}, the average lifespan {avg_lifespan}")


info = {
    "total attrition": attrition_rate,
    "total retention": retention_rate,
    "average lifespan": avg_lifespan
}
# Out:
# the attrition rate is : 31.506460315206585, the retention rate is : 68.49353968479342, the average lifespan 3.1506460315206586

# %% [markdown]
# ## 1. Telecom Metrics & Visualisations (Churn, Retention, Lifespan, CLV)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# We use tenure * MonthlyCharges. TotalCharges already captures this for the most part 
# but CLV we keep it as an different column for visualisations
df['CLV'] = df['tenure'] * df['MonthlyCharges']

# 1.2 Plots
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Churn vs Retention
labels = ['Retention', 'Churn']
sizes = [info['total retention'], info['total attrition']]
colors = ['#2ecc71', '#e74c3c']
axes[0, 0].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, shadow=True)
axes[0, 0].set_title('Global Churn Rate vs Retention Rate', fontsize=14, fontweight='bold')

# Average Lifespan (Tenure) Distribution
sns.histplot(data=df, x='tenure', hue='Churn', kde=True, bins=30, ax=axes[0, 1], palette=['#2ecc71', '#e74c3c'])
axes[0, 1].axvline(info['average lifespan'], color='blue', linestyle='--', label=f"Avg Lifespan: {info['average lifespan']:.1f} months")
axes[0, 1].set_title('Customer Lifespan (Tenure) Distribution by Churn', fontsize=14, fontweight='bold')
axes[0, 1].legend()

# CLV Distribution
sns.histplot(data=df, x='CLV', hue='Churn', kde=True, bins=30, ax=axes[1, 0], palette=['#2ecc71', '#e74c3c'])
axes[1, 0].set_title('Customer Lifetime Value (CLV) Distribution', fontsize=14, fontweight='bold')

#  CLV Boxplot
sns.boxplot(data=df, x='Churn', y='CLV', ax=axes[1, 1], palette=['#2ecc71', '#e74c3c'])
axes[1, 1].set_title('CLV by Churn Status', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_250/1548096774.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Churn', y='CLV', ax=axes[1, 1], palette=['#2ecc71', '#e74c3c'])

# %%
## --- Demographic Lifespan Analysis ---
# We'll analyze how average lifespan (tenure) varies across different demographic features
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. SeniorCitizen
sns.barplot(data=df, x='SeniorCitizen', y='tenure', ax=axes[0], palette='viridis', ci=None)
axes[0].set_title('Average Lifespan by Senior Citizen Status', fontsize=12, fontweight='bold')
axes[0].set_xticklabels(['Non-Senior (0)', 'Senior (1)'])
axes[0].set_ylabel('Average Tenure (Months)')

# 2. Partner
sns.barplot(data=df, x='Partner', y='tenure', ax=axes[1], palette='viridis', ci=None)
axes[1].set_title('Average Lifespan by Partner Status', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Average Tenure (Months)')

# 3. Dependents
sns.barplot(data=df, x='Dependents', y='tenure', ax=axes[2], palette='viridis', ci=None)
axes[2].set_title('Average Lifespan by Dependents Status', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Average Tenure (Months)')

plt.tight_layout()
plt.show()

# Interaction plot: Partner & Dependents
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Partner', y='tenure', hue='Dependents', palette='Set2', ci=None)
plt.title('Average Lifespan: Partner vs Dependents Interaction', fontsize=14, fontweight='bold')
plt.ylabel('Average Tenure (Months)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_250/3307297424.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='SeniorCitizen', y='tenure', ax=axes[0], palette='viridis', ci=None)
# /tmp/ipykernel_250/3307297424.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='SeniorCitizen', y='tenure', ax=axes[0], palette='viridis', ci=None)
# /tmp/ipykernel_250/3307297424.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Non-Senior (0)', 'Senior (1)'])
# /tmp/ipykernel_250/3307297424.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
# ...

# %%
## --- Demographic Attrition Analysis ---
# First, let's create a numeric Churn column (1 for Yes, 0 for No) to easily compute percentages
df['Churn_Numeric'] = df['Churn'].map({'Yes': 1, 'No': 0})

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. SeniorCitizen Attrition
sns.barplot(data=df, x='SeniorCitizen', y='Churn_Numeric', ax=axes[0], palette='Reds', ci=None)
axes[0].set_title('Attrition Rate by Senior Citizen Status', fontsize=12, fontweight='bold')
axes[0].set_xticklabels(['Non-Senior (0)', 'Senior (1)'])
axes[0].set_ylabel('Attrition Rate')
axes[0].set_ylim(0, 1)
axes[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y))) # format as percentage

# 2. Partner Attrition
sns.barplot(data=df, x='Partner', y='Churn_Numeric', ax=axes[1], palette='Reds', ci=None)
axes[1].set_title('Attrition Rate by Partner Status', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Attrition Rate')
axes[1].set_ylim(0, 1)
axes[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

# 3. Dependents Attrition
sns.barplot(data=df, x='Dependents', y='Churn_Numeric', ax=axes[2], palette='Reds', ci=None)
axes[2].set_title('Attrition Rate by Dependents Status', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Attrition Rate')
axes[2].set_ylim(0, 1)
axes[2].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

plt.tight_layout()
plt.show()

# Clean up the numeric column
df.drop(columns=['Churn_Numeric'], inplace=True, errors='ignore')
# Out:
# /tmp/ipykernel_250/1032089922.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='SeniorCitizen', y='Churn_Numeric', ax=axes[0], palette='Reds', ci=None)
# /tmp/ipykernel_250/1032089922.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='SeniorCitizen', y='Churn_Numeric', ax=axes[0], palette='Reds', ci=None)
# /tmp/ipykernel_250/1032089922.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Non-Senior (0)', 'Senior (1)'])
# /tmp/ipykernel_250/1032089922.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
# ...

# %% [markdown]
# ## 2. Data Preprocessing & PCA for Clustering

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Drop customerID (identifier) and target variable (Churn) for unsupervised clustering
df_cluster = df.drop(columns=['customerID', 'Churn'])

# Encode categorical variables
df_cluster_encoded = pd.get_dummies(df_cluster, drop_first=True)

# Important: Fill any remaining NaNs (e.g., TotalCharges or the 'new' column we just created)
df_cluster_encoded = df_cluster_encoded.fillna(0)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cluster_encoded)

""" To perform PCA, I will first import the `PCA` class,
 instantiate it without specifying `n_components` to analyze the explained variance,
  then fit it to the `features_preprocessed` DataFrame. After fittin
 I will visualize the cumulative explained variance ratio to determine the optimal number of components for dimensionality reduction.  """
# Instantiate PCA without specifying n_components to analyze explained variance
pca = PCA()

# Fit PCA to the preprocessed features
pca.fit(X_scaled)

# Plot the explained variance ratio by the number of components
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Number of Principal Components')
plt.grid(True)
plt.show()

print("The k-distance graph is plotted. Look for the 'elbow' point where the curve sharply changes its slope to determine the optimal epsilon value.")
# Apply PCA for dimensionality reduction (capturing 95% of variance as done previously)
pca = PCA(n_components=0.95, random_state=42)
X_pca = pca.fit_transform(X_scaled)

print(f"Original features: {df_cluster_encoded.shape[1]}")
print(f"PCA components keeping 95% variance: {X_pca.shape[1]}")
# Out:
# The k-distance graph is plotted. Look for the 'elbow' point where the curve sharply changes its slope to determine the optimal epsilon value.
# Original features: 31
# PCA components keeping 95% variance: 18

# %% [markdown]
# ## 3. Train Clustering Models (K-Means & DBSCAN)

# %%
# !pip install kneed -q
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from kneed import KneeLocator

# --- 3.1 K-Means Optimization ---
# Step 1: Use X_pca from previous cell as our dataset
X = X_pca

# Step 2: Prepare variables
k_values = range(2, 11)  # Start from 2 because silhouette score needs at least 2 clusters
inertia_values = []
silhouette_scores = []

# Step 3: Run KMeans for each k
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    inertia_values.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X, kmeans.labels_))

# Step 4: Find elbow point automatically
kneedle = KneeLocator(k_values, inertia_values, curve='convex', direction='decreasing')
optimal_k_elbow = kneedle.knee

# Step 5: Find best silhouette score
optimal_k_silhouette = k_values[np.argmax(silhouette_scores)]

# Step 6: Plot Elbow Method
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(k_values, inertia_values, marker='o')
plt.axvline(optimal_k_elbow, color='r', linestyle='--', label=f'Elbow k={optimal_k_elbow}')
plt.title("Elbow Method")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia")
plt.legend()
plt.grid(True)

# Step 7: Plot Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(k_values, silhouette_scores, marker='o', color='orange')
plt.axvline(optimal_k_silhouette, color='g', linestyle='--', label=f'Best silhouette k={optimal_k_silhouette}')
plt.title("Silhouette Score Method")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Step 8: Print results
print(f"Optimal k (Elbow Method): {optimal_k_elbow}")
print(f"Optimal k (Silhouette Score): {optimal_k_silhouette}")

# Train Final KMeans
best_k = optimal_k_silhouette if optimal_k_silhouette else optimal_k_elbow
print(f"\nTraining Final KMeans with K={best_k}")

kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
df['KMeans_Cluster'] = kmeans.fit_predict(X)
# Out:
# Optimal k (Elbow Method): 4
# Optimal k (Silhouette Score): 2
#
# Training Final KMeans with K=2

# %% [markdown]
# ### K-Distance Graph for DBSCAN Epsilon Tuning\n
# Before running a grid search, we can use the k-distance graph to approximate the optimal `eps`. The idea is to calculate the distance to the k-th nearest neighbor for each point, sort these distances, and plot them. The 'elbow' of defining this curve represents a good choice for `eps`.

# %%
# Compute k-distance graph to find optimal eps for DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt

# Using min_samples = 30 as a starting point, so we look at the 30th nearest neighbor
# For min_samples = 30, we technically look at the 29-th nearest neighbor depending on the implementation
# But n_neighbors=30 in sklearn retrieves the nearest 30 including the point itself.
min_samples = 30
neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_pca)
distances, indices = neighbors_fit.kneighbors(X_pca)

# Sort distances
distances = np.sort(distances, axis=0)
distances = distances[:, min_samples - 1] # get the distance to the furthest neighbor

plt.figure(figsize=(10, 5))
plt.plot(distances)
plt.title('K-distance Graph (k=30)')
plt.xlabel('Data Points sorted by distance')
plt.ylabel('Epsilon (30th Nearest Neighbor Distance)')
plt.grid(True)
plt.show()

# Look for the 'elbow' in this graph to determine a good starting point for eps in grid search

# %%
import itertools

# --- 3.2 DBSCAN Grid Search ---
# For DBSCAN, we need to iterate over eps and min_samples
eps_values = np.arange(0.5, 3.5, 0.5)
min_samples_values = range(10, 51, 10)

best_eps = -1
best_min_samples = -1
best_db_score = -1

print("Starting DBSCAN Grid Search...")
for eps, min_samples in itertools.product(eps_values, min_samples_values):
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    preds = dbscan.fit_predict(X_pca)
    
   
    unique_labels = set(preds)
    if len(unique_labels) > 1 and not (len(unique_labels) == 2 and -1 in unique_labels): 
       
        try:
            score = silhouette_score(X_pca, preds)
            if score > best_db_score:
                best_db_score = score
                best_eps = eps
                best_min_samples = min_samples
        except ValueError:
            pass

print(f"Best DBSCAN params: eps={best_eps}, min_samples={best_min_samples} with silhouette score: {best_db_score:.4f}")

# Train Final DBSCAN
print(f"\nTraining Final DBSCAN with optimized parameters...")
if best_eps != -1:
    dbscan = DBSCAN(eps=best_eps, min_samples=best_min_samples)
else:
    # fallback if grid search didn't find any configuration with >1 cluster
    print("Grid search failed to find valid clusters, using fallback parameters eps=2.1, min_samples=30")
    dbscan = DBSCAN(eps=2.1, min_samples=30)
    
df['DBSCAN_Cluster'] = dbscan.fit_predict(X_pca)

noise_pct = (df['DBSCAN_Cluster'] == -1).mean() * 100
print(f"DBSCAN Noise points: {noise_pct:.2f}%")
# Out:
# Starting DBSCAN Grid Search...
# Best DBSCAN params: eps=3.0, min_samples=50 with silhouette score: 0.1621
#
# Training Final DBSCAN with optimized parameters...
# DBSCAN Noise points: 41.30%

# %% [markdown]
# ## 4. t-SNE Dimensionality Reduction & Cluster Visualisation

# %%
from sklearn.manifold import TSNE

# Fit t-SNE on the PCA data to reduce it down to 2 dimensions for visualisation
print("Running t-SNE (this might take a minute)...")
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(X_pca)

df['tsne_1'] = X_tsne[:, 0]
df['tsne_2'] = X_tsne[:, 1]
print("t-SNE complete.")
# Out:
# Running t-SNE (this might take a minute)...
# t-SNE complete.

# %% [markdown]
# ## 4.1 Comparing K-Means (K=2 vs K=4) using t-SNE
#
# Since the Silhouette Score suggested 2 clusters and the Elbow Method suggested 4 clusters, let's visualize both using our t-SNE projection.

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# Train KMeans for K=2 and K=4 on the PCA data
kmeans_2 = KMeans(n_clusters=2, random_state=42, n_init=10)
df['KMeans_Cluster_2'] = kmeans_2.fit_predict(X_pca)

kmeans_4 = KMeans(n_clusters=4, random_state=42, n_init=10)
df['KMeans_Cluster_4'] = kmeans_4.fit_predict(X_pca)

# Plot the 2 comparative scatter plots
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# Plot for K=2
sns.scatterplot(
    data=df, x='tsne_1', y='tsne_2', hue='KMeans_Cluster_2',
    palette='tab10', ax=axes[0], alpha=0.6, s=30
)
axes[0].set_title('t-SNE coloured by K-Means Clusters (K=2)', fontsize=14, fontweight='bold')

# Plot for K=4
sns.scatterplot(
    data=df, x='tsne_1', y='tsne_2', hue='KMeans_Cluster_4',
    palette='tab10', ax=axes[1], alpha=0.6, s=30
)
axes[1].set_title('t-SNE coloured by K-Means Clusters (K=4)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# comparative scatter plots
fig, axes = plt.subplots(2, 2, figsize=(18, 16))

# True Churn
sns.scatterplot(
    data=df, x='tsne_1', y='tsne_2', hue='Churn',
    palette=['#2ecc71', '#e74c3c'], ax=axes[0, 0], alpha=0.6, s=30
)
axes[0, 0].set_title('t-SNE coloured by True Churn Status', fontsize=14, fontweight='bold')

#CLV
scatter_clv = axes[0, 1].scatter(
    df['tsne_1'], df['tsne_2'], c=df['CLV'],
    cmap='viridis', alpha=0.6, s=30
)
plt.colorbar(scatter_clv, ax=axes[0, 1], label='CLV')
axes[0, 1].set_title('t-SNE coloured by Customer Lifetime Value (CLV)', fontsize=14, fontweight='bold')

#KMeans Clusters
sns.scatterplot(
    data=df, x='tsne_1', y='tsne_2', hue='KMeans_Cluster_4',
    palette='tab10', ax=axes[1, 0], alpha=0.6, s=30
)
axes[1, 0].set_title('t-SNE coloured by K-Means Clusters', fontsize=14, fontweight='bold')

# DBSCAN Clusters
sns.scatterplot(
    data=df, x='tsne_1', y='tsne_2', hue='DBSCAN_Cluster',
    palette='Set1', ax=axes[1, 1], alpha=0.6, s=30
)
axes[1, 1].set_title('t-SNE coloured by DBSCAN Clusters (-1 is noise)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
